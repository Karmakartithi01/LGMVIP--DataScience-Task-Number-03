# %% [markdown]
# #**Data Science Intern at LetsGrowMore**
#
# **Name : Tithi Karmakar**
#
#
# **Task 03 : Image to Pencil Sketch with Python:**

# %% [markdown]
# **Importing the libraries**

# %%
#importing numpy,matplotlib,and cv2 library.
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# **Reading The Input Image**

# %%
img =cv2.imread("/content/jerry.jpg")# read the image
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(img)
plt.show()

# %% [markdown]
# **Converting Original Image to Grey Scale**

# %%
gray_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)#converting the grey scale image
plt.axis('off')
plt.imshow(gray_img)
plt.show()

# %% [markdown]
# **Inverting the Gray Image**

# %%
#inv_gray_img = 255 - gray_img
inv_gray_img = cv2.bitwise_not(gray_img)
plt.axis('off')
plt.imshow(inv_gray_img)
plt.show()

# %% [markdown]
# **Blurring the inverted gray image by Gausian Function**

# %%
blur_img = cv2.GaussianBlur(inv_gray_img,(21,21),0)
plt.axis('off')
plt.imshow(blur_img)
plt.show()

# %% [markdown]
# **Inverting the blurred image**

# %%
#inv_blur_img = 255 - blur_img
inv_blur_img = cv2.bitwise_not(blur_img)
plt.axis('off')
plt.imshow(inv_blur_img)
plt.show()

# %% [markdown]
# **Creating Pencil Sketch image**

# %%
pencil_img = cv2.divide(gray_img,inv_blur_img,scale = 256.0)
plt.axis('off')
fig, ax = plt.subplots(figsize=(6, 6), facecolor='white')
ax.axis('off')
ax.imshow(pencil_img, cmap='gray')
plt.show()

# %%
cv2.imwrite("./output_image.png",pencil_img)
# Out:
# True

# %% [markdown]
# **Converted a RGB image to pencil sketch using Python.**
